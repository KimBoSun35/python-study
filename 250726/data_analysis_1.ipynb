# %%
import pandas as pd

# %%
df=pd.read_excel('20250408_음식DB.xlsx', engine="openpyxl")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14584 entries, 0 to 14583
# Columns: 159 entries, 식품코드 to 데이터기준일자
# dtypes: datetime64[ns](2), float64(129), int64(9), object(19)
# memory usage: 17.7+ MB

# %%
df.head()
# Out:
#                   식품코드      식품명 데이터구분코드 데이터구분명  식품기원코드       식품기원명  식품대분류코드  \
# 0  D101-004160000-0001  국밥_돼지머리       D     음식       1  가정식(분석 함량)        1
# 1  D101-004310000-0001  국밥_순대국밥       D     음식       1  가정식(분석 함량)        1
# 2  D101-004500000-0001   국밥_콩나물       D     음식       1  가정식(분석 함량)        1
# 3  D101-006000000-0001      기장밥       D     음식       1  가정식(분석 함량)        1
# 4  D101-007000000-0001       김밥       D     음식       1  가정식(분석 함량)        1
#
#   식품대분류명  대표식품코드 대표식품명  ...  토코페롤(mg) 토코트리에놀(mg)  출처코드       출처명  식품중량   업체명  \
# 0     밥류    1004    국밥  ...      0.30       0.04     3  식품의약품안전처  900g  해당없음
# 1     밥류    1004    국밥  ...      0.33       0.06     3  식품의약품안전처  900g  해당없음
# 2     밥류    1004    국밥  ...      0.33       0.04     3  식품의약품안전처  780g  해당없음
# 3     밥류    1006   기장밥  ...      0.22       0.21     3  식품의약품안전처  200g  해당없음
# 4     밥류    1007    김밥  ...      0.98       0.09     3  식품의약품안전처  230g  해당없음
#
#   데이터생성방법코드  데이터생성방법명    데이터생성일자    데이터기준일자
# 0         1        분석 2017-12-31 2025-04-08
# 1         1        분석 2017-12-31 2025-04-08
# 2         1        분석 2018-12-31 2025-04-08
# 3         1        분석 2017-12-31 2025-04-08
# 4         1        분석 2018-12-31 2025-04-08
#
# [5 rows x 159 columns]

# %%
df.columns
# Out:
# Index(['식품코드', '식품명', '데이터구분코드', '데이터구분명', '식품기원코드', '식품기원명', '식품대분류코드',
#        '식품대분류명', '대표식품코드', '대표식품명',
#        ...
#        '토코페롤(mg)', '토코트리에놀(mg)', '출처코드', '출처명', '식품중량', '업체명', '데이터생성방법코드',
#        '데이터생성방법명', '데이터생성일자', '데이터기준일자'],
#       dtype='object', length=159)

# %%
input_food = input("정보를 알고싶은 음식명을 입력하세요 : ")
df[df['식품명'].str.contains(input_food)][['식품코드','식품명','식품대분류명','대표식품명','에너지(kcal)']]
# Out:
# 정보를 알고싶은 음식명을 입력하세요 :  김밥
#                       식품코드          식품명 식품대분류명  대표식품명  에너지(kcal)
# 4      D101-007000000-0001           김밥     밥류     김밥        140
# 5      D101-007070000-0001        김밥_김치     밥류     김밥        130
# 6      D101-007090000-0001       김밥_날치알     밥류     김밥        177
# 7      D101-007120000-0001       김밥_돈가스     밥류     김밥        202
# 8      D101-007280000-0001       김밥_소고기     밥류     김밥        179
# 9      D101-007450000-0001        김밥_참치     밥류     김밥        174
# 10     D101-007480000-0001        김밥_채소     밥류     김밥        158
# 11     D101-007490000-0001        김밥_치즈     밥류     김밥        177
# 12     D101-007520000-0001       김밥_풋고추     밥류     김밥        169
# 30     D101-019460000-0001  삼각김밥_참치마요네즈     밥류   삼각김밥        199
# 10803  D301-007270000-0001       김밥_샐러드     밥류     김밥        162
# 10804  D301-007280000-0001       김밥_소고기     밥류     김밥        160
# 10805  D301-007450000-0002        김밥_참치     밥류     김밥        170
# 10825  D301-019040000-0001  삼각김밥_고추장불고기     밥류   삼각김밥        165
# 10826  D301-019320000-0001    삼각김밥_숯불갈비     밥류   삼각김밥        161
# 10827  D301-019460000-0001  삼각김밥_참치마요네즈     밥류   삼각김밥        172
# 10847  D301-043000000-0001         충무김밥     밥류   충무김밥        146
# 11447  D401-007030000-0001        김밥_계란     밥류     김밥         97
# 11448  D401-007070000-0001        김밥_김치     밥류     김밥        109
# 11449  D401-007090000-0001       김밥_날치알     밥류     김밥        104
# 11450  D401-007120000-0001       김밥_돈가스     밥류     김밥        148
# 11451  D401-007190400-0001     김밥_멸치_고추     밥류     김밥        122
# 11452  D401-007270000-0001       김밥_샐러드     밥류     김밥        117
# 11453  D401-007280000-0001       김밥_소고기     밥류     김밥        108
# 11454  D401-007450000-0001        김밥_참치     밥류     김밥        128
# 11455  D401-007450400-0001     김밥_참치_고추     밥류     김밥        119
# 11456  D401-007455900-0001     김밥_참치_김치     밥류     김밥        125
# 11457  D401-007480000-0001        김밥_채소     밥류     김밥        102
# 11458  D401-007490000-0001        김밥_치즈     밥류     김밥        122
# 11459  D401-007560000-0001        김밥_고추     밥류     김밥         94
# 11460  D401-007610000-0001       김밥_샐러리     밥류     김밥        130
# 11480  D401-019000000-0001         삼각김밥     밥류   삼각김밥        185
# 11503  D401-043000000-0001         충무김밥     밥류   충무김밥        128
# 11522  D401-064000000-0001        모듬 김밥     밥류  모듬 김밥        113
# 12457  D501-007000000-0001           김밥     밥류     김밥        185
# 12458  D501-007030000-0001        김밥_계란     밥류     김밥         99
# 12459  D501-007480000-0001        김밥_채소     밥류     김밥        102
# 13181  D601-007450000-0001        김밥_참치     밥류     김밥        129
# 13182  D601-007480000-0001        김밥_채소     밥류     김밥        102
# 13798  D701-007000000-0001           김밥     밥류     김밥        157
# 13799  D701-007280000-0001       김밥_소고기     밥류     김밥        110
# 13800  D701-007450000-0001        김밥_참치     밥류     김밥        128
# 13801  D701-007480000-0001        김밥_채소     밥류     김밥        105
# 13816  D701-019000000-0001         삼각김밥     밥류   삼각김밥        183

# %%
df[df["식품명"]=="영양돌솥밥"][["식품코드", "식품명", "식품대분류명", "대표식품명", "에너지(kcal)"]]
# Out:
#                       식품코드    식품명 식품대분류명  대표식품명  에너지(kcal)
# 33     D101-026000000-0001  영양돌솥밥     밥류  영양돌솥밥        184
# 11483  D401-026000000-0001  영양돌솥밥     밥류  영양돌솥밥        119
# 12479  D501-026000000-0001  영양돌솥밥     밥류  영양돌솥밥        111
# 13205  D601-026000000-0001  영양돌솥밥     밥류  영양돌솥밥        114
# 13819  D701-026000000-0001  영양돌솥밥     밥류  영양돌솥밥        131

# %%
df[df["식품명"]=="김치"][["식품코드", "식품명", "식품대분류명", "대표식품명", "에너지(kcal)"]]
# Out:
# Empty DataFrame
# Columns: [식품코드, 식품명, 식품대분류명, 대표식품명, 에너지(kcal)]
# Index: []

# %%
df[df["식품명"]=="닭튀김"][["식품코드", "식품명", "식품대분류명", "대표식품명", "에너지(kcal)"]]
# Out:
#                       식품코드  식품명 식품대분류명 대표식품명  에너지(kcal)
# 11309  D312-549000000-0001  닭튀김    튀김류   닭튀김        301
# 12183  D412-549000000-0001  닭튀김    튀김류   닭튀김        155
# 12988  D512-549000000-0001  닭튀김    튀김류   닭튀김        183
# 13634  D612-549000000-0001  닭튀김    튀김류   닭튀김        153
# 14360  D712-549000000-0001  닭튀김    튀김류   닭튀김        172

# %%
df[df["식품명"].str.contains("닭튀김")][["식품코드", "식품명", "식품대분류명", "대표식품명", "에너지(kcal)"]]
# Out:
#                       식품코드                 식품명  식품대분류명    대표식품명  에너지(kcal)
# 374    D112-549040000-0001              닭튀김_날개     튀김류      닭튀김        257
# 6366   D212-549000000-0001  닭튀김_No.1포테이토닥토닭 치킨     튀김류      닭튀김        286
# 6367   D212-549000000-0002           닭튀김_간장 치킨     튀김류      닭튀김        327
# 6368   D212-549000000-0003           닭튀김_간장 치킨     튀김류      닭튀김        233
# 6369   D212-549000000-0004           닭튀김_간장 치킨     튀김류      닭튀김        275
# ...                    ...                 ...     ...      ...        ...
# 13635  D612-549160000-0001              닭튀김_양념     튀김류      닭튀김        128
# 13757  D614-672000000-0001             닭튀김 샐러드  생채·무침류  닭튀김 샐러드         79
# 14360  D712-549000000-0001                 닭튀김     튀김류      닭튀김        172
# 14361  D712-549160000-0001              닭튀김_양념     튀김류      닭튀김        222
# 14525  D714-672000000-0001             닭튀김 샐러드  생채·무침류  닭튀김 샐러드         79
#
# [166 rows x 5 columns]

# %%
input_food = input("정보를 알고싶은 음식명을 입력하세요 : ")
df[df['식품명'].str.contains(input_food)][['식품코드','식품명','식품대분류명','대표식품명','에너지(kcal)']]
# Out:
# 정보를 알고싶은 음식명을 입력하세요 :  닭튀김
#                       식품코드                 식품명  식품대분류명    대표식품명  에너지(kcal)
# 374    D112-549040000-0001              닭튀김_날개     튀김류      닭튀김        257
# 6366   D212-549000000-0001  닭튀김_No.1포테이토닥토닭 치킨     튀김류      닭튀김        286
# 6367   D212-549000000-0002           닭튀김_간장 치킨     튀김류      닭튀김        327
# 6368   D212-549000000-0003           닭튀김_간장 치킨     튀김류      닭튀김        233
# 6369   D212-549000000-0004           닭튀김_간장 치킨     튀김류      닭튀김        275
# ...                    ...                 ...     ...      ...        ...
# 13635  D612-549160000-0001              닭튀김_양념     튀김류      닭튀김        128
# 13757  D614-672000000-0001             닭튀김 샐러드  생채·무침류  닭튀김 샐러드         79
# 14360  D712-549000000-0001                 닭튀김     튀김류      닭튀김        172
# 14361  D712-549160000-0001              닭튀김_양념     튀김류      닭튀김        222
# 14525  D714-672000000-0001             닭튀김 샐러드  생채·무침류  닭튀김 샐러드         79
#
# [166 rows x 5 columns]

# %%
#열량 구하기
input_food = input("정보를 알고싶은 음식명을 입력하세요 : ")
df[df['식품명'].str.contains(input_food)][['식품명', '에너지(kcal)']]
# Out:
# 정보를 알고싶은 음식명을 입력하세요 :  김밥
#                식품명  에너지(kcal)
# 4               김밥        140
# 5            김밥_김치        130
# 6           김밥_날치알        177
# 7           김밥_돈가스        202
# 8           김밥_소고기        179
# 9            김밥_참치        174
# 10           김밥_채소        158
# 11           김밥_치즈        177
# 12          김밥_풋고추        169
# 30     삼각김밥_참치마요네즈        199
# 10803       김밥_샐러드        162
# 10804       김밥_소고기        160
# 10805        김밥_참치        170
# 10825  삼각김밥_고추장불고기        165
# 10826    삼각김밥_숯불갈비        161
# 10827  삼각김밥_참치마요네즈        172
# 10847         충무김밥        146
# 11447        김밥_계란         97
# 11448        김밥_김치        109
# 11449       김밥_날치알        104
# 11450       김밥_돈가스        148
# 11451     김밥_멸치_고추        122
# 11452       김밥_샐러드        117
# 11453       김밥_소고기        108
# 11454        김밥_참치        128
# 11455     김밥_참치_고추        119
# 11456     김밥_참치_김치        125
# 11457        김밥_채소        102
# 11458        김밥_치즈        122
# 11459        김밥_고추         94
# 11460       김밥_샐러리        130
# 11480         삼각김밥        185
# 11503         충무김밥        128
# 11522        모듬 김밥        113
# 12457           김밥        185
# 12458        김밥_계란         99
# 12459        김밥_채소        102
# 13181        김밥_참치        129
# 13182        김밥_채소        102
# 13798           김밥        157
# 13799       김밥_소고기        110
# 13800        김밥_참치        128
# 13801        김밥_채소        105
# 13816         삼각김밥        183

# %%
input_food = input("정보를 알고싶은 음식명을 입력하세요 : ")
a=df[df['식품명'].str.contains(input_food)]['에너지(kcal)']
for i in a:
    print(i)
# Out:
# 정보를 알고싶은 음식명을 입력하세요 :  삼각김밥_참치마요네즈
# 199
# 172

# %%
#input_food = input("정보를 알고싶은 음식명을 입력하세요 : ")
search_info=df[df['식품명'].str.contains("삼각김밥_참치마요네즈")]['에너지(kcal)']
for i in search_info:
    print(i)
# Out:
# 199
# 172

# %%
# 열량구하기
#음식의 열령을 출력하고
#1. DB 등록 음식 중 상위 몇 %에 해당하는 음식인지 출력하기
#2. 100g당 열랴으>>>g을 입력하면 열랑을 계산해서 알려주기

search_info=df[df['식품명'].str.contains("삼각김밥_참치마요네즈")][['식품명', '에너지(kcal)']]
for i in range(len(search_info)):
    print(search_info.iloc[i]["식품명"], search_info.iloc[i]["에너지(kcal)"])
# Out:
# 삼각김밥_참치마요네즈 199
# 삼각김밥_참치마요네즈 172

# %%
# 열량구하기
#음식의 열령을 출력하고
#1. DB 등록 음식 중 상위 몇 %에 해당하는 음식인지 출력하기
#2. 100g당 열랴으>>>g을 입력하면 열랑을 계산해서 알려주기
input_food=input("식품명을 입력하세요 :")
input_weight=input("g을 입력하세요 :")
search_info=df[df['식품명'].str.contains(input_food)][['식품명', '에너지(kcal)']]
for i in range(len(search_info)):
    final_kcal=int(search_info.iloc[i]["에너지(kcal)"]) / 100 * int(input_weight)
    print(search_info.iloc[i]["식품명"], search_info.iloc[i]["에너지(kcal)"])
# Out:
# 식품명을 입력하세요 : 황금올리브
# g을 입력하세요 : 300
# 닭다리튀김_황금올리브치킨 닭다리 244
# 닭튀김_핫황금올리브 치킨 크리스피 323
# 닭튀김_핫황금올리브 치킨 크리스피 반마리 323
# 닭튀김_황금올리브 치킨 254
# 닭튀김_황금올리브 치킨 반마리 254
# 닭튀김_황금올리브 치킨 레드착착 308
# 닭튀김_황금올리브 치킨 레드착착 반마리 154
# 닭튀김_황금올리브 치킨 블랙페퍼 304
# 닭튀김_황금올리브 치킨 블랙페퍼 반마리 304
# 닭튀김_황금올리브 치킨 속안심 269
# 닭튀김_황금올리브 치킨 콤보 288
# 닭튀김_황금올리브 치킨 크런치 버터 301
# 닭튀김_황금올리브 치킨 핫윙 313
# 닭튀김_황금올리브 치킨 핫윙 냉장 313

# %%
input_food=input("식품명을 입력하세요 :")
input_weight=input("g을 입력하세요 :")
search_info=df[df['식품명'].str.contains(input_food)][['식품명', '에너지(kcal)']]
for i in range(len(search_info)):
    final_kcal=int(search_info.iloc[i]["에너지(kcal)"]) / 100 * int(input_weight)
    print(search_info.iloc[i]["식품명"], search_info.iloc[i]["에너지(kcal)"])
# Out:
# 식품명을 입력하세요 : 닭백숙
# g을 입력하세요 : 300
# 닭백숙 56
# 닭백숙 102

# %%
input_food = input("정보를 알고싶은 음식명을 입력하세요 : ")

search_info = df[df['식품명'].str.contains(input_food)][['식품명', '에너지(kcal)']]

for i in range(len(search_info)):
    #print("index:", search_info.index[i])
    print("index:", i)
    print("식품명:", search_info.iloc[i]['식품명'])
    # print("에너지(kcal):", search_info.iloc[i]['에너지(kcal)'])
    print("---")
# Out:
# 정보를 알고싶은 음식명을 입력하세요 :  황금올리브
# index: 0
# 식품명: 닭다리튀김_황금올리브치킨 닭다리
# ---
# index: 1
# 식품명: 닭튀김_핫황금올리브 치킨 크리스피
# ---
# index: 2
# 식품명: 닭튀김_핫황금올리브 치킨 크리스피 반마리
# ---
# index: 3
# 식품명: 닭튀김_황금올리브 치킨
# ---
# index: 4
# 식품명: 닭튀김_황금올리브 치킨 반마리
# ---
# index: 5
# 식품명: 닭튀김_황금올리브 치킨 레드착착
# ---
# index: 6
# 식품명: 닭튀김_황금올리브 치킨 레드착착 반마리
# ---
# index: 7
# 식품명: 닭튀김_황금올리브 치킨 블랙페퍼
# ---
# index: 8
# 식품명: 닭튀김_황금올리브 치킨 블랙페퍼 반마리
# ---
# index: 9
# 식품명: 닭튀김_황금올리브 치킨 속안심
# ---
# index: 10
# 식품명: 닭튀김_황금올리브 치킨 콤보
# ---
# index: 11
# 식품명: 닭튀김_황금올리브 치킨 크런치 버터
# ---
# index: 12
# 식품명: 닭튀김_황금올리브 치킨 핫윙
# ---
# index: 13
# 식품명: 닭튀김_황금올리브 치킨 핫윙 냉장
# ---

# %%
input_index = input("선택 할 식품의 index를 입력하세요 : ")
result_kcal = search_info.iloc[int(input_index)]['에너지(kcal)']
input_weight = input("선택 할 식품의 g 수를 입력하세요 : ")
final_kcal = int(result_kcal)*int(input_weight)/100
print("검색한 음식의 100g당 열량은",result_kcal,"kcal 이며,")
print("입력하신 ",input_weight,"g 의 총 열량은",final_kcal,"kcal 입니다.")
# Out:
# 선택 할 식품의 index를 입력하세요 :  5
# 선택 할 식품의 g 수를 입력하세요 :  500
# 검색한 음식의 100g당 열량은 308 kcal 이며,
# 입력하신  500 g 의 총 열량은 1540.0 kcal 입니다.

# %%
##### 상위 몇 퍼센트에 위치하는가?
input_food = input("정보를 알고싶은 음식명을 입력하세요 : ")

search_info = df[df['식품명'].str.contains(input_food)][['식품명', '에너지(kcal)']]

for i in range(len(search_info)):
    #print("index:", search_info.index[i])
    print("index:", i)
    print("식품명:", search_info.iloc[i]['식품명'])
    # print("에너지(kcal):", search_info.iloc[i]['에너지(kcal)'])
    print("---")

input_index = input("선택 할 식품의 index를 입력하세요 : ")
result_kcal = search_info.iloc[int(input_index)]['에너지(kcal)']

result=search_info.iloc[int(input_index)]

print(result.name)
# Out:
# 정보를 알고싶은 음식명을 입력하세요 :  황금올리브
# index: 0
# 식품명: 닭다리튀김_황금올리브치킨 닭다리
# ---
# index: 1
# 식품명: 닭튀김_핫황금올리브 치킨 크리스피
# ---
# index: 2
# 식품명: 닭튀김_핫황금올리브 치킨 크리스피 반마리
# ---
# index: 3
# 식품명: 닭튀김_황금올리브 치킨
# ---
# index: 4
# 식품명: 닭튀김_황금올리브 치킨 반마리
# ---
# index: 5
# 식품명: 닭튀김_황금올리브 치킨 레드착착
# ---
# index: 6
# 식품명: 닭튀김_황금올리브 치킨 레드착착 반마리
# ---
# index: 7
# 식품명: 닭튀김_황금올리브 치킨 블랙페퍼
# ---
# index: 8
# 식품명: 닭튀김_황금올리브 치킨 블랙페퍼 반마리
# ---
# index: 9
# 식품명: 닭튀김_황금올리브 치킨 속안심
# ---
# index: 10
# 식품명: 닭튀김_황금올리브 치킨 콤보
# ---
# index: 11
# 식품명: 닭튀김_황금올리브 치킨 크런치 버터
# ---
# index: 12
# 식품명: 닭튀김_황금올리브 치킨 핫윙
# ---
# index: 13
# 식품명: 닭튀김_황금올리브 치킨 핫윙 냉장
# ---
# 선택 할 식품의 index를 입력하세요 :  5
# 6493

# %%
df_sorted= df.sort_values("에너지(kcal)")
df_sorted[["식품명", "에너지(kcal)"]]
# Out:
#                        식품명  에너지(kcal)
# 7291                녹차_그린티          0
# 10660      허브차_페어진저 핫(HOT)          0
# 10661   허브차_페퍼민트 아이스(ICED)          0
# 10662   허브차_페퍼민트 아이스(ICED)          0
# 10663   허브차_페퍼민트 아이스(ICED)          0
# ...                    ...        ...
# 887            머핀_휘낭시에 소시지        667
# 2385   케이크_당 충전100 쇼콜라 케이크        704
# 13011                뱅어포튀김        732
# 2592           크림빵_브리오슈슈크레        740
# 2522        크로와상_해시브라운 크로플        808
#
# [14584 rows x 2 columns]

# %%
##### 상위 몇 퍼센트에 위치하는가?
input_food = input("정보를 알고싶은 음식명을 입력하세요 : ")

search_info = df[df['식품명'].str.contains(input_food)][['식품명', '에너지(kcal)']]

for i in range(len(search_info)):
    #print("index:", search_info.index[i])
    print("index:", i)
    print("식품명:", search_info.iloc[i]['식품명'])
    # print("에너지(kcal):", search_info.iloc[i]['에너지(kcal)'])
    print("---")

input_index = input("선택 할 식품의 index를 입력하세요 : ")
result_kcal = search_info.iloc[int(input_index)]['에너지(kcal)']

result=search_info.iloc[int(input_index)]

print(result.name)
# Out:
# 정보를 알고싶은 음식명을 입력하세요 :  김밥
# index: 0
# 식품명: 김밥
# ---
# index: 1
# 식품명: 김밥_김치
# ---
# index: 2
# 식품명: 김밥_날치알
# ---
# index: 3
# 식품명: 김밥_돈가스
# ---
# index: 4
# 식품명: 김밥_소고기
# ---
# index: 5
# 식품명: 김밥_참치
# ---
# index: 6
# 식품명: 김밥_채소
# ---
# index: 7
# 식품명: 김밥_치즈
# ---
# index: 8
# 식품명: 김밥_풋고추
# ---
# index: 9
# 식품명: 삼각김밥_참치마요네즈
# ---
# index: 10
# 식품명: 김밥_샐러드
# ---
# index: 11
# 식품명: 김밥_소고기
# ---
# index: 12
# 식품명: 김밥_참치
# ---
# index: 13
# 식품명: 삼각김밥_고추장불고기
# ---
# index: 14
# 식품명: 삼각김밥_숯불갈비
# ---
# index: 15
# 식품명: 삼각김밥_참치마요네즈
# ---
# index: 16
# 식품명: 충무김밥
# ---
# index: 17
# 식품명: 김밥_계란
# ---
# index: 18
# 식품명: 김밥_김치
# ---
# index: 19
# 식품명: 김밥_날치알
# ---
# index: 20
# 식품명: 김밥_돈가스
# ---
# index: 21
# 식품명: 김밥_멸치_고추
# ---
# index: 22
# 식품명: 김밥_샐러드
# ---
# index: 23
# 식품명: 김밥_소고기
# ---
# index: 24
# 식품명: 김밥_참치
# ---
# index: 25
# 식품명: 김밥_참치_고추
# ---
# index: 26
# 식품명: 김밥_참치_김치
# ---
# index: 27
# 식품명: 김밥_채소
# ---
# index: 28
# 식품명: 김밥_치즈
# ---
# index: 29
# 식품명: 김밥_고추
# ---
# index: 30
# 식품명: 김밥_샐러리
# ---
# index: 31
# 식품명: 삼각김밥
# ---
# index: 32
# 식품명: 충무김밥
# ---
# index: 33
# 식품명: 모듬 김밥
# ---
# index: 34
# 식품명: 김밥
# ---
# index: 35
# 식품명: 김밥_계란
# ---
# index: 36
# 식품명: 김밥_채소
# ---
# index: 37
# 식품명: 김밥_참치
# ---
# index: 38
# 식품명: 김밥_채소
# ---
# index: 39
# 식품명: 김밥
# ---
# index: 40
# 식품명: 김밥_소고기
# ---
# index: 41
# 식품명: 김밥_참치
# ---
# index: 42
# 식품명: 김밥_채소
# ---
# index: 43
# 식품명: 삼각김밥
# ---
# 선택 할 식품의 index를 입력하세요 :  41
# 13800

# %%
df_sorted= df.sort_values("에너지(kcal)")
df_sorted[["식품명", "에너지(kcal)"]]

cnt=0
for i in range(len(df_sorted)):
    #print(df_sorted.iloc[i].name)
    #print(df_sorted.iloc[i]['식품명'])
    #print(df_sorted.iloc[i]['에너지(kcal)'])
    if result.name==df_sorted.iloc[i].name:
        break
        
    cnt +=1
print(cnt)
print(cnt/148584*100,"%")
# Out:
# 6888
# 4.635761589403973 %
